# %%
import numpy as np
import pandas as pd
from pandas.io.parsers import read_csv
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(6.4, 4.8))
x = [1, 2, 16, 32, 32, 64, 128, 128, 256, 256, 512, 512, 512, 512, 1024, 1024, 2048, 2048, 4096, 4096, 4096, 8192, 16384, 16384]
y = [40.111, 138.339, 244.567, 65.890, 63.573, 46.817, 34.311, 31.527, 33.003, 28.878, 31.155, 30.225, 30.692, 30.692, 31.564, 31.857, 32.049, 30.125, 33.606, 29.180, 34.666, 32.574, 120.085, 120.280]
x1 = [128, 1, 2, 64, 512, 2048, 8192, 32768]
y1 = [40.374, 37.614, 179.855, 43.695, 31.147, 30.845, 30.939, 53.989]
plt.scatter(x, y, color='C0', label='ParList rdeepseq')
plt.scatter(x1, y1, color='C1', label='Par Monad')
plt.xscale('log', basex=2)
plt.xlim(left=1)
plt.ylim(bottom=1)
plt.plot()

plt.xlabel('Number of chunks/blocks/sparks')
plt.ylabel('Total runtime (s)')
plt.title('Number of blocks vs runtime for naive solution at 8 threads')
plt.legend()
plt.savefig('total_times_naive.png')

# %%
plt.figure(figsize=(6.4, 4.8))
x = [1, 32, 32, 64, 128, 128, 256, 256, 512, 512, 512, 512, 1024, 1024, 2048, 2048, 4096, 4096, 4096, 8192]
y = [40.111, 65.890, 63.573, 46.817, 34.311, 31.527, 33.003, 28.878, 31.155, 30.225, 30.692, 30.692, 31.564, 31.857, 32.049, 30.125, 33.606, 29.180, 34.666, 32.574]
plt.scatter(x, y)
plt.xscale('log', basex=2)
plt.xlim(left=1)
plt.ylim(bottom=1)
plt.plot()

plt.xlabel('Number of chunks/blocks')
plt.ylabel('Total runtime (s)')
plt.title('Number of blocks vs runtime for naive solution at 8 threads (trimmed)')
plt.savefig('total_times_naive_trimmed.png')

# %%
plt.figure(figsize=(6.4, 4.8))
x = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 12228, 16384]
y = [48.337, 23.207, 11.461, 8.064, 7.555, 7.391, 7.294, 7.558, 7.687, 7.403, 7.361, 7.481, 7.470, 8.810, 46.832, 39.682]
x1 = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536]
y1 = [45.972, 22.939, 11.867, 7.940, 7.872, 7.597, 7.741, 7.431, 7.498, 7.638, 7.721, 7.604, 7.293, 7.361, 7.402, 7.431, 7.432]
plt.scatter(x1, y1, color='C1', label='Par Monad')
plt.scatter(x, y, color='C0', label='ParList rdeepseq')
plt.xscale('log', basex=2)
plt.xlim(left=1)
plt.ylim(bottom=1)
plt.plot()

plt.xlabel("Number of chunks/blocks")
plt.ylabel("Total runtime (s)")
plt.title('Number of blocks vs runtime at 8 threads')
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[::-1], labels[::-1], loc='upper center')
plt.savefig('total_times.png')

# %%
plt.figure(figsize=(6.4, 4.8))
x = [1, 1, 2, 3, 4, 4, 5, 6, 7, 8, 8, 8, 8, 9, 9, 10, 11, 12, 12]
y = [35.475, 35.968, 19.129, 12.892, 10.153, 10.557, 8.301, 7.917, 7.820, 7.824, 7.550, 7.298, 7.314, 7.717, 7.550, 7.003, 7.050, 9.485, 9.911]
x1 = [1, 2, 3, 4, 5, 6, 6, 7, 8, 8, 9, 10, 11, 12]
y1 = [36.162, 18.460, 12.812, 9.881, 8.491, 8.417, 8.243, 8.613, 7.167, 8.295, 7.291, 8.596, 8.052, 9.233]
plt.scatter(x1, y1, color='C1', label='Par Monad')
plt.scatter(x, y, color='C0', label='ParList rdeepseq')
plt.xlim(left=0)
plt.ylim(bottom=1)
plt.plot()

plt.xlabel("Number of threads")
plt.ylabel("Total runtime (s)")
plt.title('Number of threads vs runtime at 128 blocks')
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[::-1], labels[::-1])
plt.savefig('total_times_threads.png')
